# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, make_scorer, fbeta_score
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.neural_network import MLPClassifier

# %%
#preprocess data: Outlier,log
from sklearn.feature_selection import VarianceThreshold
from sklearn.base import BaseEstimator, TransformerMixin

class OutlierCapper(BaseEstimator, TransformerMixin):
    def __init__(self, lower_percentile=1, upper_percentile=99):
        self.lower_percentile = lower_percentile
        self.upper_percentile = upper_percentile

    def fit(self, X, y=None):
        self.lower_bounds = np.percentile(X, self.lower_percentile, axis=0)
        self.upper_bounds = np.percentile(X, self.upper_percentile, axis=0)
        return self

    def transform(self, X):
        return np.clip(X, self.lower_bounds, self.upper_bounds)
        
def preprocess_and_split_data():
    """
    Load the dataset, apply log transformation to specified columns, handle outliers,
    remove zero-variance features, and combine the target variable back.

    Returns:
    tuple: (X, y) where X is the feature DataFrame and y is the target Series.
    """
    # Load the dataset (fixed path)
    data = pd.read_csv('E:\coursentu\MH6805ml\project\data.csv')

    # Remove leading and trailing whitespace from column names
    data.columns = data.columns.str.strip()

    # Define the columns to be log-transformed and the target variable
    log_transform_columns = [
        'Cash Turnover Rate',
        'Quick Asset Turnover Rate',
        'Inventory Turnover Rate (times)',
        'Total Asset Growth Rate',
        'Research and development expense rate'
    ]
    target_variable = 'Bankrupt?'

    # Extract the target variable before further processing
    y = data[target_variable]
    X = data.drop(columns=[target_variable])

    # Apply log transformation to specified columns
    for column in log_transform_columns:
        if column in X.columns:  # Check if the column is in X
            # Apply log transformation: if value is greater than 0, apply log, otherwise keep it as 0
            X[column] = np.where(X[column] > 0, np.log(X[column]), 0)
    print(f"Applied log transformation to columns: {log_transform_columns}")

    # Filter out rows where any of the non-log-transformed columns have values >1 or <0
    non_log_columns = [col for col in X.columns if col not in log_transform_columns]
    condition = X[non_log_columns].apply(lambda row: ((row <= 1) & (row >= 0)).all(), axis=1)
    X = X[condition].reset_index(drop=True)
    y = y[condition].reset_index(drop=True)
    print("Filtered out rows with values >1 or <0 in non-log-transformed columns.")

    # Handle outliers using OutlierCapper
    outlier_capper = OutlierCapper(lower_percentile=1, upper_percentile=99)
    outlier_capper.fit(X)
    X = outlier_capper.transform(X)
    print("Capped outliers in the data.")

    # Combine processed features with the target variable
    processed_data = pd.concat([X, y], axis=1)
    print(f"Combined processed features with target variable. Final data shape: {processed_data.shape}")

    # Save the transformed data to a new CSV file
    processed_data.to_csv('E:\coursentu\MH6805ml\project\data_transformed2.csv', index=False)
    print("Saved the transformed data to 'data_transformed2.csv'.")

    return X, y

if __name__ == '__main__':
    X, y = preprocess_and_split_data()
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y,random_state=42)
# Out:
# <>:27: SyntaxWarning: invalid escape sequence '\c'
# <>:71: SyntaxWarning: invalid escape sequence '\c'
# <>:27: SyntaxWarning: invalid escape sequence '\c'
# <>:71: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28024\3462248716.py:27: SyntaxWarning: invalid escape sequence '\c'
#   data = pd.read_csv('E:\coursentu\MH6805ml\project\data.csv')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28024\3462248716.py:71: SyntaxWarning: invalid escape sequence '\c'
#   processed_data.to_csv('E:\coursentu\MH6805ml\project\data_transformed2.csv', index=False)
# D:\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Applied log transformation to columns: ['Cash Turnover Rate', 'Quick Asset Turnover Rate', 'Inventory Turnover Rate (times)', 'Total Asset Growth Rate', 'Research and development expense rate']
# Filtered out rows with values >1 or <0 in non-log-transformed columns.
# Capped outliers in the data.
# Combined processed features with target variable. Final data shape: (2920, 96)
# Saved the transformed data to 'data_transformed2.csv'.

# %% [markdown]
# **Sampling Compare for RandomForest**

# %%
from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler, EditedNearestNeighbours
from imblearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer, fbeta_score, balanced_accuracy_score
import pandas as pd

# Define the techniques to evaluate
oversampling_methods = [SMOTE(sampling_strategy=0.5), ADASYN(sampling_strategy=0.5)]
undersampling_methods = [RandomUnderSampler(sampling_strategy=0.8), EditedNearestNeighbours()]

# Define the F2 scorer
balanced_accuracy_scorer = make_scorer(balanced_accuracy_score)

# Evaluate each combination
results = []
for over in oversampling_methods:
    for under in undersampling_methods:
        steps = [
            ('over', over),
            ('under', under),
            ('classifier', RandomForestClassifier(random_state=42))  # Add the classifier here
        ]
        pipeline = Pipeline(steps=steps)
        
        # Apply the pipeline to the training data and evaluate the model using cross-validation
        balanced_accuracy_scores = cross_val_score(pipeline, X_train, y_train, scoring=balanced_accuracy_scorer, cv=5)
        
        results.append({
            'oversampler': over.__class__.__name__,
            'undersampler': under.__class__.__name__,
            'mean_balanced_accuracy': balanced_accuracy_scores.mean()            
        })

# Convert results to a DataFrame for easy comparison
results_sample_df = pd.DataFrame(results)

# Print results
print(results_sample_df)
# Out:
#   oversampler             undersampler  mean_balanced_accuracy
# 0       SMOTE       RandomUnderSampler                0.660828
# 1       SMOTE  EditedNearestNeighbours                0.663605
# 2      ADASYN       RandomUnderSampler                0.661231
# 3      ADASYN  EditedNearestNeighbours                0.654985

# %% [markdown]
# Best Technique would be SMOTE+EditedNearestNeighbours

# %% [markdown]
# **Feature Selection with PCA**

# %%
from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import EditedNearestNeighbours
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import balanced_accuracy_score
import numpy as np
import pandas as pd

def apply_pca(X, variance_threshold=0.90):
    # Remove constant columns
    selector = VarianceThreshold(threshold=0.0)
    X_filtered = selector.fit_transform(X)
    pca = PCA(n_components=variance_threshold)
    X_pca = pca.fit_transform(X_filtered)  
    
    return X_pca, pca  

def get_pca_feature_importance(pca, initial_feature_names):
    n_pcs = pca.components_.shape[0]
    most_important = [np.abs(pca.components_[i]).argmax() for i in range(n_pcs)]
    most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]
    explained_variance = pca.explained_variance_ratio_
    
    dic = {
        'PC{}'.format(i + 1): {
            'Most Important Feature': most_important_names[i],
            'Explained Variance': explained_variance[i]
        } for i in range(n_pcs)
    }
    
    df = pd.DataFrame(dic).T  
    return df

if __name__ == '__main__':
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
    
    # Apply SMOTE followed by Edited Nearest Neighbours
    smote = SMOTE(random_state=42)
    X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)
    enn = EditedNearestNeighbours()
    X_train_balanced, y_train_balanced = enn.fit_resample(X_train_smote, y_train_smote)

    # Scale the balanced training data
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_balanced)
    X_test_scaled = scaler.transform(X_test)
    
    # Apply PCA on the training data
    X_train_pca, pca = apply_pca(X_train_scaled)
    
    # Transform the test data using the fitted PCA model
    X_test_filtered = VarianceThreshold(threshold=0.0).fit(X_train_scaled).transform(X_test_scaled)
    X_test_pca = pca.transform(X_test_filtered)

    # RandomForestClassifier
    model = RandomForestClassifier(random_state=42)
    
    # Cross-validation
    cv_scores = cross_val_score(model, X_train_pca, y_train_balanced, cv=5, scoring='balanced_accuracy')
    print('Cross-validated balanced accuracy scores:', cv_scores)
    print('Mean balanced accuracy:', cv_scores.mean())

    # Evaluation with
    model.fit(X_train_pca, y_train_balanced)
    y_pred = model.predict(X_test_pca)
    balanced_acc = balanced_accuracy_score(y_test, y_pred)
    print('Test Balanced Accuracy:', balanced_acc)

    # Get the initial feature names after preprocessing
    feature_names_after_scaler = X.columns.tolist()  # Original feature names

    # Get PCA feature importance
    pca_feature_importance_df = get_pca_feature_importance(pca, feature_names_after_scaler)

    print(pca_feature_importance_df)
    number_of_components = pca.n_components_
    print('Number of components:', number_of_components)

    PCs = ['PC{}'.format(i + 1) for i in range(number_of_components)]
    components_df = pd.DataFrame(pca.components_)
    components_df = components_df.T
    components_df.columns = PCs
    print(components_df.head(5))
# Out:
# Cross-validated balanced accuracy scores: [0.98577681 0.98905908 0.98576225 0.98795043 0.9923268 ]
# Mean balanced accuracy: 0.9881750741119903
# Test Balanced Accuracy: 0.7228883200862185
#                        Most Important Feature Explained Variance
# PC1   Persistent EPS in the Last Four Seasons           0.324732
# PC2                             Current Ratio           0.107319
# PC3               Current Asset Turnover Rate           0.065718
# PC4                      Total Asset Turnover             0.0605
# PC5                 Cash Flow to Total Assets           0.045535
# PC6                    Operating Gross Margin           0.033779
# PC7                       Cash Flow to Equity           0.030797
# PC8                 Quick Asset Turnover Rate           0.029675
# PC9             Current Liabilities/Liability            0.02785
# PC10       Degree of Financial Leverage (DFL)           0.023851
# PC11         After-tax Net Profit Growth Rate           0.020054
# PC12                   Cash/Current Liability           0.017159
# PC13          Inventory Turnover Rate (times)           0.015126
# PC14                  Net Value Per Share (B)           0.014634
# PC15     Long-term fund suitability ratio (A)           0.013463
# PC16  Realized Sales Gross Profit Growth Rate           0.011731
# PC17         Contingent liabilities/Net worth           0.010772
# PC18          Inventory Turnover Rate (times)           0.009532
# PC19    Research and development expense rate           0.009146
# PC20      Interest-bearing debt interest rate           0.008844
# PC21                Inventory/Working Capital           0.008135
# PC22                             Tax rate (A)           0.007865
# PC23                  Total Asset Growth Rate           0.007573
# Number of components: 23
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  0.162215 -0.112875  0.016762  0.003102 -0.039773  0.036372 -0.003715
# 1  0.162040 -0.114961  0.040775 -0.014470 -0.047913  0.001087  0.011177
# 2  0.161787 -0.115187  0.023061 -0.004988 -0.040481  0.021701  0.006129
# 3  0.116283  0.060920 -0.006355 -0.001049 -0.115440  0.330725 -0.026662
# 4  0.116061  0.062135 -0.007012 -0.000037 -0.114327  0.330225 -0.027013
#
#         PC8       PC9      PC10  ...      PC14      PC15      PC16      PC17  \
# 0 -0.036699 -0.009916 -0.034471  ... -0.025012  0.036386  0.036070 -0.007700
# 1 -0.040855 -0.041283 -0.032566  ... -0.029866  0.035779  0.035152 -0.003477
# 2 -0.036876 -0.027265 -0.035843  ... -0.031859  0.037081  0.037332 -0.018772
# 3 -0.132955  0.056807 -0.004964  ... -0.080355  0.107407 -0.016448  0.055463
# 4 -0.133593  0.056421 -0.004514  ... -0.083728  0.108212 -0.016213  0.053674
#
#        PC18      PC19      PC20      PC21      PC22      PC23
# 0 -0.072071  0.003897 -0.044956 -0.039882 -0.043636 -0.006249
# 1 -0.049143 -0.017661 -0.057055  0.001061 -0.017812  0.004895
# 2 -0.060457  0.002825 -0.053128 -0.029431 -0.070533  0.005008
# 3  0.042642 -0.011954 -0.000389  0.044541  0.092188  0.026728
# 4  0.041549 -0.008984 -0.000968  0.045153  0.090260  0.023619
#
# [5 rows x 23 columns]

# %% [markdown]
# Balanced accuracy increases 6%

# %% [markdown]
# **Bayesian Optimization**
#
# Bayesian optimization uses probability to find the minimum of a function. The final aim is to find the input value to a function which can gives us the lowest possible output value.It usually performs better than random,grid and manual search providing better performance in the testing phase and reduced optimization time. In Hyperopt, Bayesian Optimization can be implemented giving 3 three main parameters to the function fmin.
#
# Objective Function = defines the loss function to minimize.
# Domain Space = defines the range of input values to test (in Bayesian Optimization this space creates a probability distribution for each of the used Hyperparameters).
# Optimization Algorithm = defines the search algorithm to use to select the best input values to use in each new iteration.

# %%
from hyperopt import hp,fmin,tpe,STATUS_OK,Trials
from sklearn.datasets import make_classification

space = {'criterion': hp.choice('criterion', ['entropy', 'gini']),
        'max_depth': hp.choice('max_depth', range(10, 1200, 10)),
        'max_features': hp.choice('max_features', ['sqrt','log2', None]),
        'min_samples_leaf': hp.uniform('min_samples_leaf', 0, 0.5),
        'min_samples_split' : hp.uniform ('min_samples_split', 0, 1),
        'n_estimators' : hp.choice('n_estimators', [10, 50, 300, 750, 1200,1300,1500])
    }

def objective(space):
    model = RandomForestClassifier(criterion = space['criterion'], max_depth = space['max_depth'],
                                 max_features = space['max_features'],
                                 min_samples_leaf = space['min_samples_leaf'],
                                 min_samples_split = space['min_samples_split'],
                                 n_estimators = space['n_estimators'], 
                                 )
    
    accuracy = cross_val_score(model, X_train, y_train, cv = 5).mean()

    # We aim to maximize accuracy, therefore we return it as a negative value
    return {'loss': -accuracy, 'status': STATUS_OK }

if __name__ == '__main__':
    trials = Trials()
    best = fmin(fn= objective,
                space= space,
                algo= tpe.suggest,
                max_evals = 80,
                trials= trials)

    crit = {0: 'entropy', 1: 'gini'}
    feat = {0: 'sqrt', 1: 'log2', 2: None}
    est = {0: 10, 1: 50, 2: 300, 3: 750, 4: 1200,5:1300,6:1500}
    print(crit[best['criterion']])
    print(feat[best['max_features']])
    print(est[best['n_estimators']])

    model = RandomForestClassifier(criterion = crit[best['criterion']], max_depth = best['max_depth'], 
                                       max_features = feat[best['max_features']], 
                                       min_samples_leaf = best['min_samples_leaf'], 
                                       min_samples_split = best['min_samples_split'], 
                                       n_estimators = est[best['n_estimators']]).fit(X_train_pca, y_train_balanced)
    y_pred = model.predict(X_test_pca)
    balanced_acc = balanced_accuracy_score(y_test, y_pred)
    print('Test Balanced Accuracy:', balanced_acc)
# Out:
# 100%|█████████████████████████████████████████████| 80/80 [1:00:17<00:00, 45.22s/trial, best loss: -0.9781685243141345]
# entropy
# None
# 10
# Test Balanced Accuracy: 0.8976155193318065

# %%
print('criterion：',crit[best['criterion']])
print('max_depth：',best['max_depth'])
print('max_features：',feat[best['max_features']])
print('min_samples_leaf：',best['min_samples_leaf'])
print('min_samples_split：',best['min_samples_split'])
print('n_estimators：',est[best['n_estimators']])
# Out:
# criterion： entropy
# max_depth： 5
# max_features： None
# min_samples_leaf： 0.14178808464739434
# min_samples_split： 0.20246315200981757
# n_estimators： 10

# %%
conf_matrix_pca = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix_pca)
print('Test Balanced Accuracy:', balanced_acc)
# Out:
# Confusion Matrix:
# [[499  72]
#  [  1  12]]
# Test Balanced Accuracy: 0.8984911760743635

# %%
model_nopca = RandomForestClassifier(criterion = crit[best['criterion']], max_depth = best['max_depth'], 
                                       max_features = feat[best['max_features']], 
                                       min_samples_leaf = best['min_samples_leaf'], 
                                       min_samples_split = best['min_samples_split'], 
                                       n_estimators = est[best['n_estimators']]).fit(X_train_scaled, y_train_balanced)
y_pred_nopca = model_nopca.predict(X_test_scaled)
balanced_acc_nopca = balanced_accuracy_score(y_test, y_pred_nopca)
conf_matrix_nopca = confusion_matrix(y_test, y_pred_nopca)
print('Confusion Matrix:')
print(conf_matrix_nopca)
print('Test Balanced Accuracy:', balanced_acc_nopca)
# Out:
# Confusion Matrix:
# [[477  94]
#  [  2  11]]
# Test Balanced Accuracy: 0.8407651892765728

# %% [markdown]
# With Bayesian Optimization, balanced accuracy increases 17%. Compared with no pca, balanced accuracy increases 5%.

# %% [markdown]
# **ANN**

# %%
from sklearn.model_selection import train_test_split
from tensorflow import keras 
from tensorflow.keras import layers, callbacks
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import GridSearchCV,train_test_split,

smote = SMOTE(sampling_strategy='minority')
X_sm, y_sm = smote.fit_resample(X,y)
X_ann, y_ann = enn.fit_resample(X_sm, y_sm)

X_train_ann, X_test_ann, y_train_ann, y_test_ann = train_test_split(X_ann, y_ann, test_size=0.2, random_state = 101, stratify = y_ann)
scaler = StandardScaler()
X_train_ann = scaler.fit_transform(X_train_ann)
X_test_ann = scaler.transform(X_test_ann)
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

model_ann_nopca = keras.Sequential([
    keras.layers.Dense(190, activation='relu', input_shape=[95]),
    layers.Dropout(0.5),
    keras.layers.Dense(100,activation='relu'),
    layers.Dropout(0.5),
    keras.layers.Dense(1,activation='sigmoid')
])

model_ann_nopca.compile(
    optimizer='adam',
    metrics=['accuracy'],
    loss='binary_crossentropy'
)

history_ann_nopca = model_ann_nopca.fit(X_train_ann, y_train_ann,
                                        epochs=500,
                                        validation_data=(X_test_ann, y_test_ann), verbose=1,
                                        batch_size=100,
                                        callbacks=[early_stop])
loss_ann_nopca, accuracy_ann_nopca = model_ann_nopca.evaluate(X_test_ann,y_test_ann)
print(f'Test Loss: {loss_ann_nopca:.4f}, Test Accuracy: {accuracy_ann_nopca:.4f}')

y_pred_ann_nopca = model_ann_nopca.predict(X_test_ann)  
y_pred_classes_ann_nopca = (y_pred_ann_nopca > 0.5).astype(int)  

balanced_acc_ann_nopca = balanced_accuracy_score(y_test_ann, y_pred_classes_ann_nopca)
print(f'Test Balanced Accuracy: {balanced_acc_ann_nopca:.4f}')

print(f'Test Loss: {loss_ann_nopca:.4f}, Test Accuracy: {accuracy_ann_nopca:.4f}')
print(f'Test Balanced Accuracy: {balanced_acc_ann_nopca:.4f}')
conf_matrix_ann_nopca = confusion_matrix(y_test_ann, y_pred_classes_ann_nopca)
print('Confusion Matrix:')
print(conf_matrix_ann_nopca)

plt.figure(figsize=(12, 6))
plt.plot(history_ann_nopca.history['loss'], label='Training Loss')
plt.plot(history_ann_nopca.history['val_loss'], label='Validation Loss')
plt.title('Loss Function')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1/500
# D:\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7746 - loss: 0.4560 - val_accuracy: 0.9408 - val_loss: 0.1677
# Epoch 2/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9271 - loss: 0.1990 - val_accuracy: 0.9585 - val_loss: 0.1352
# Epoch 3/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9565 - loss: 0.1388 - val_accuracy: 0.9647 - val_loss: 0.1150
# Epoch 4/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9585 - loss: 0.1316 - val_accuracy: 0.9691 - val_loss: 0.1011
# Epoch 5/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9655 - loss: 0.1078 - val_accuracy: 0.9744 - val_loss: 0.0926
# Epoch 6/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9686 - loss: 0.1042 - val_accuracy: 0.9744 - val_loss: 0.0874
# Epoch 7/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9743 - loss: 0.0897 - val_accuracy: 0.9753 - val_loss: 0.0790
# Epoch 8/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9761 - loss: 0.0788 - val_accuracy: 0.9797 - val_loss: 0.0691
# Epoch 9/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9792 - loss: 0.0701 - val_accuracy: 0.9797 - val_loss: 0.0748
# Epoch 10/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9843 - loss: 0.0586 - val_accuracy: 0.9823 - val_loss: 0.0639
# Epoch 11/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9859 - loss: 0.0552 - val_accuracy: 0.9841 - val_loss: 0.0599
# Epoch 12/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9863 - loss: 0.0469 - val_accuracy: 0.9841 - val_loss: 0.0489
# Epoch 13/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9871 - loss: 0.0427 - val_accuracy: 0.9850 - val_loss: 0.0425
# Epoch 14/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9877 - loss: 0.0406 - val_accuracy: 0.9850 - val_loss: 0.0454
# Epoch 15/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9907 - loss: 0.0379 - val_accuracy: 0.9859 - val_loss: 0.0375
# Epoch 16/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9906 - loss: 0.0341 - val_accuracy: 0.9850 - val_loss: 0.0496
# Epoch 17/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9928 - loss: 0.0248 - val_accuracy: 0.9859 - val_loss: 0.0371
# Epoch 18/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9925 - loss: 0.0276 - val_accuracy: 0.9850 - val_loss: 0.0404
# Epoch 19/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9899 - loss: 0.0268 - val_accuracy: 0.9885 - val_loss: 0.0428
# Epoch 20/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9928 - loss: 0.0300 - val_accuracy: 0.9867 - val_loss: 0.0391
# Epoch 21/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - loss: 0.0166 - val_accuracy: 0.9876 - val_loss: 0.0299
# Epoch 22/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9945 - loss: 0.0179 - val_accuracy: 0.9850 - val_loss: 0.0473
# Epoch 23/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9955 - loss: 0.0143 - val_accuracy: 0.9894 - val_loss: 0.0372
# Epoch 24/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - loss: 0.0185 - val_accuracy: 0.9876 - val_loss: 0.0404
# Epoch 25/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9952 - loss: 0.0169 - val_accuracy: 0.9867 - val_loss: 0.0372
# Epoch 26/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9961 - loss: 0.0158 - val_accuracy: 0.9920 - val_loss: 0.0276
# Epoch 27/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9976 - loss: 0.0120 - val_accuracy: 0.9912 - val_loss: 0.0274
# Epoch 28/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9966 - loss: 0.0114 - val_accuracy: 0.9894 - val_loss: 0.0369
# Epoch 29/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9973 - loss: 0.0095 - val_accuracy: 0.9920 - val_loss: 0.0296
# Epoch 30/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9980 - loss: 0.0084 - val_accuracy: 0.9947 - val_loss: 0.0286
# Epoch 31/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9983 - loss: 0.0076 - val_accuracy: 0.9929 - val_loss: 0.0273
# Epoch 32/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9962 - loss: 0.0144 - val_accuracy: 0.9947 - val_loss: 0.0262
# Epoch 33/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9977 - loss: 0.0084 - val_accuracy: 0.9903 - val_loss: 0.0358
# Epoch 34/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9985 - loss: 0.0065 - val_accuracy: 0.9938 - val_loss: 0.0267
# Epoch 35/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9978 - loss: 0.0102 - val_accuracy: 0.9903 - val_loss: 0.0343
# Epoch 36/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9978 - loss: 0.0057 - val_accuracy: 0.9947 - val_loss: 0.0216
# Epoch 37/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9967 - loss: 0.0100 - val_accuracy: 0.9912 - val_loss: 0.0259
# Epoch 38/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9955 - loss: 0.0117 - val_accuracy: 0.9903 - val_loss: 0.0370
# Epoch 39/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9975 - loss: 0.0092 - val_accuracy: 0.9929 - val_loss: 0.0239
# Epoch 40/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9975 - loss: 0.0104 - val_accuracy: 0.9876 - val_loss: 0.0465
# Epoch 41/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9968 - loss: 0.0133 - val_accuracy: 0.9920 - val_loss: 0.0303
# Epoch 42/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0066 - val_accuracy: 0.9912 - val_loss: 0.0404
# Epoch 43/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9982 - loss: 0.0052 - val_accuracy: 0.9947 - val_loss: 0.0270
# Epoch 44/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9989 - loss: 0.0061 - val_accuracy: 0.9876 - val_loss: 0.0486
# Epoch 45/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9968 - loss: 0.0072 - val_accuracy: 0.9920 - val_loss: 0.0312
# Epoch 46/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9967 - loss: 0.0092 - val_accuracy: 0.9903 - val_loss: 0.0388
# Epoch 47/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.0044 - val_accuracy: 0.9920 - val_loss: 0.0295
# Epoch 48/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9969 - loss: 0.0088 - val_accuracy: 0.9912 - val_loss: 0.0309
# Epoch 49/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9988 - loss: 0.0059 - val_accuracy: 0.9920 - val_loss: 0.0356
# Epoch 50/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9985 - loss: 0.0034 - val_accuracy: 0.9929 - val_loss: 0.0349
# Epoch 51/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9968 - loss: 0.0102 - val_accuracy: 0.9920 - val_loss: 0.0271
# Epoch 52/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9983 - loss: 0.0143 - val_accuracy: 0.9903 - val_loss: 0.0435
# Epoch 53/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9991 - loss: 0.0034 - val_accuracy: 0.9929 - val_loss: 0.0320
# Epoch 54/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0029 - val_accuracy: 0.9920 - val_loss: 0.0332
# Epoch 55/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9986 - loss: 0.0045 - val_accuracy: 0.9929 - val_loss: 0.0298
# Epoch 56/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0045 - val_accuracy: 0.9920 - val_loss: 0.0319
# Epoch 57/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9990 - loss: 0.0056 - val_accuracy: 0.9929 - val_loss: 0.0167
# Epoch 58/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9999 - loss: 0.0021 - val_accuracy: 0.9938 - val_loss: 0.0216
# Epoch 59/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9994 - loss: 0.0029 - val_accuracy: 0.9929 - val_loss: 0.0283
# Epoch 60/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9986 - loss: 0.0032 - val_accuracy: 0.9947 - val_loss: 0.0168
# Epoch 61/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9929 - val_loss: 0.0236
# Epoch 62/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9990 - loss: 0.0029 - val_accuracy: 0.9965 - val_loss: 0.0166
# Epoch 63/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9981 - loss: 0.0055 - val_accuracy: 0.9894 - val_loss: 0.0520
# Epoch 64/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9984 - loss: 0.0051 - val_accuracy: 0.9929 - val_loss: 0.0356
# Epoch 65/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9986 - loss: 0.0092 - val_accuracy: 0.9903 - val_loss: 0.0440
# Epoch 66/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0058 - val_accuracy: 0.9929 - val_loss: 0.0263
# Epoch 67/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9992 - loss: 0.0025 - val_accuracy: 0.9920 - val_loss: 0.0204
# Epoch 68/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 0.9938 - val_loss: 0.0205
# Epoch 69/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9988 - loss: 0.0062 - val_accuracy: 0.9920 - val_loss: 0.0220
# Epoch 70/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9992 - loss: 0.0020 - val_accuracy: 0.9920 - val_loss: 0.0256
# Epoch 71/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9929 - val_loss: 0.0309
# Epoch 72/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9988 - loss: 0.0071 - val_accuracy: 0.9938 - val_loss: 0.0224
# Epoch 73/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9998 - loss: 0.0018 - val_accuracy: 0.9938 - val_loss: 0.0239
# Epoch 74/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9993 - loss: 0.0019 - val_accuracy: 0.9938 - val_loss: 0.0182
# Epoch 75/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9991 - loss: 0.0041 - val_accuracy: 0.9938 - val_loss: 0.0212
# Epoch 76/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9988 - loss: 0.0044 - val_accuracy: 0.9938 - val_loss: 0.0323
# Epoch 77/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9983 - loss: 0.0059 - val_accuracy: 0.9929 - val_loss: 0.0365
# Epoch 78/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9982 - loss: 0.0068 - val_accuracy: 0.9920 - val_loss: 0.0447
# Epoch 79/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9981 - loss: 0.0064 - val_accuracy: 0.9920 - val_loss: 0.0240
# Epoch 80/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9978 - loss: 0.0144 - val_accuracy: 0.9947 - val_loss: 0.0270
# Epoch 81/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9993 - loss: 0.0025 - val_accuracy: 0.9929 - val_loss: 0.0279
# Epoch 82/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9976 - loss: 0.0073 - val_accuracy: 0.9920 - val_loss: 0.0292
# Epoch 83/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9983 - loss: 0.0053 - val_accuracy: 0.9929 - val_loss: 0.0271
# Epoch 84/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.9929 - val_loss: 0.0262
# Epoch 85/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 0.9929 - val_loss: 0.0210
# Epoch 86/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9981 - loss: 0.0055 - val_accuracy: 0.9938 - val_loss: 0.0192
# Epoch 87/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9982 - loss: 0.0037 - val_accuracy: 0.9956 - val_loss: 0.0172
# Epoch 88/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 0.9947 - val_loss: 0.0225
# Epoch 89/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9980 - loss: 0.0031 - val_accuracy: 0.9947 - val_loss: 0.0159
# Epoch 90/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9982 - loss: 0.0096 - val_accuracy: 0.9929 - val_loss: 0.0403
# Epoch 91/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9993 - loss: 0.0018 - val_accuracy: 0.9947 - val_loss: 0.0308
# Epoch 92/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9988 - loss: 0.0027 - val_accuracy: 0.9947 - val_loss: 0.0275
# Epoch 93/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9979 - loss: 0.0072 - val_accuracy: 0.9938 - val_loss: 0.0332
# Epoch 94/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9990 - loss: 0.0029 - val_accuracy: 0.9947 - val_loss: 0.0271
# Epoch 95/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9985 - loss: 0.0048 - val_accuracy: 0.9956 - val_loss: 0.0198
# Epoch 96/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9986 - loss: 0.0036 - val_accuracy: 0.9938 - val_loss: 0.0246
# Epoch 97/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9996 - loss: 0.0019 - val_accuracy: 0.9938 - val_loss: 0.0268
# Epoch 98/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9947 - val_loss: 0.0271
# Epoch 99/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9988 - loss: 0.0040 - val_accuracy: 0.9912 - val_loss: 0.0334
# Epoch 100/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0015 - val_accuracy: 0.9929 - val_loss: 0.0320
# Epoch 101/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9992 - loss: 0.0018 - val_accuracy: 0.9956 - val_loss: 0.0234
# Epoch 102/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9991 - loss: 0.0036 - val_accuracy: 0.9956 - val_loss: 0.0211
# Epoch 103/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9994 - loss: 0.0017 - val_accuracy: 0.9920 - val_loss: 0.0339
# Epoch 104/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9988 - loss: 0.0025 - val_accuracy: 0.9938 - val_loss: 0.0219
# Epoch 105/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9947 - val_loss: 0.0214
# Epoch 106/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9988 - loss: 0.0030 - val_accuracy: 0.9956 - val_loss: 0.0102
# Epoch 107/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 0.9947 - val_loss: 0.0097
# Epoch 108/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 4.7009e-04 - val_accuracy: 0.9947 - val_loss: 0.0122
# Epoch 109/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9929 - val_loss: 0.0228
# Epoch 110/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0028 - val_accuracy: 0.9912 - val_loss: 0.0436
# Epoch 111/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9988 - loss: 0.0029 - val_accuracy: 0.9956 - val_loss: 0.0264
# Epoch 112/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9947 - val_loss: 0.0292
# Epoch 113/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 6.3359e-04 - val_accuracy: 0.9947 - val_loss: 0.0285
# Epoch 114/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9968 - loss: 0.0068 - val_accuracy: 0.9929 - val_loss: 0.0344
# Epoch 115/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9947 - val_loss: 0.0261
# Epoch 116/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9999 - loss: 5.7941e-04 - val_accuracy: 0.9965 - val_loss: 0.0204
# Epoch 117/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9938 - val_loss: 0.0256
# Epoch 118/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9993 - loss: 0.0022 - val_accuracy: 0.9947 - val_loss: 0.0253
# Epoch 119/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9990 - loss: 0.0055 - val_accuracy: 0.9938 - val_loss: 0.0244
# Epoch 120/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9992 - loss: 0.0026 - val_accuracy: 0.9947 - val_loss: 0.0320
# Epoch 121/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9999 - loss: 8.9830e-04 - val_accuracy: 0.9956 - val_loss: 0.0286
# Epoch 122/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9972 - loss: 0.0112 - val_accuracy: 0.9912 - val_loss: 0.0294
# Epoch 123/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9972 - loss: 0.0133 - val_accuracy: 0.9894 - val_loss: 0.0489
# Epoch 124/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9983 - loss: 0.0072 - val_accuracy: 0.9894 - val_loss: 0.0415
# Epoch 125/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9988 - loss: 0.0039 - val_accuracy: 0.9929 - val_loss: 0.0266
# Epoch 126/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0163 - val_accuracy: 0.9903 - val_loss: 0.0385
# Epoch 127/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 0.9903 - val_loss: 0.0289
# Epoch 128/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9992 - loss: 0.0030 - val_accuracy: 0.9894 - val_loss: 0.0386
# Epoch 129/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9991 - loss: 0.0016 - val_accuracy: 0.9912 - val_loss: 0.0254
# Epoch 130/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9991 - loss: 0.0056 - val_accuracy: 0.9938 - val_loss: 0.0187
# Epoch 131/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9996 - loss: 0.0026 - val_accuracy: 0.9947 - val_loss: 0.0177
# Epoch 132/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9993 - loss: 0.0027 - val_accuracy: 0.9929 - val_loss: 0.0265
# Epoch 133/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9938 - val_loss: 0.0225
# Epoch 134/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9993 - loss: 0.0035 - val_accuracy: 0.9938 - val_loss: 0.0277
# Epoch 135/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0040 - val_accuracy: 0.9929 - val_loss: 0.0260
# Epoch 136/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9992 - loss: 0.0021 - val_accuracy: 0.9929 - val_loss: 0.0319
# Epoch 137/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9992 - loss: 0.0020 - val_accuracy: 0.9912 - val_loss: 0.0365
# Epoch 138/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9996 - loss: 0.0020 - val_accuracy: 0.9929 - val_loss: 0.0293
# Epoch 139/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 7.4226e-04 - val_accuracy: 0.9929 - val_loss: 0.0317
# Epoch 140/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9992 - loss: 0.0014 - val_accuracy: 0.9929 - val_loss: 0.0288
# Epoch 141/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.5012e-04 - val_accuracy: 0.9929 - val_loss: 0.0292
# Epoch 142/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9947 - val_loss: 0.0203
# Epoch 143/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.5551e-04 - val_accuracy: 0.9947 - val_loss: 0.0236
# Epoch 144/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9992 - loss: 0.0016 - val_accuracy: 0.9912 - val_loss: 0.0337
# Epoch 145/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9996 - loss: 0.0045 - val_accuracy: 0.9956 - val_loss: 0.0298
# Epoch 146/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9997 - loss: 8.0700e-04 - val_accuracy: 0.9938 - val_loss: 0.0321
# Epoch 147/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.0037 - val_accuracy: 0.9938 - val_loss: 0.0267
# Epoch 148/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.9828e-04 - val_accuracy: 0.9929 - val_loss: 0.0321
# Epoch 149/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9992 - loss: 0.0037 - val_accuracy: 0.9956 - val_loss: 0.0234
# Epoch 150/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9988 - loss: 0.0024 - val_accuracy: 0.9938 - val_loss: 0.0257
# Epoch 151/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 4.6462e-04 - val_accuracy: 0.9929 - val_loss: 0.0282
# Epoch 152/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9997 - loss: 0.0016 - val_accuracy: 0.9947 - val_loss: 0.0187
# Epoch 153/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.0847e-04 - val_accuracy: 0.9938 - val_loss: 0.0221
# Epoch 154/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9938 - val_loss: 0.0207
# Epoch 155/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9938 - val_loss: 0.0215
# Epoch 156/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9989 - loss: 0.0052 - val_accuracy: 0.9929 - val_loss: 0.0234
# Epoch 157/500
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9983 - loss: 0.0041 - val_accuracy: 0.9929 - val_loss: 0.0267
# Epoch 157: early stopping
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9919 - loss: 0.0288
# Test Loss: 0.0267, Test Accuracy: 0.9929
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Test Balanced Accuracy: 0.9930

# %%
print(f'Test Loss: {loss_ann_nopca:.4f}, Test Accuracy: {accuracy_ann_nopca:.4f}')
print(f'Test Balanced Accuracy: {balanced_acc_ann_nopca:.4f}')
conf_matrix_ann_nopca = confusion_matrix(y_test_ann, y_pred_classes_ann_nopca)
print('Confusion Matrix:')
print(conf_matrix_ann_nopca)
# Out:
# Test Loss: 0.0267, Test Accuracy: 0.9929
# Test Balanced Accuracy: 0.9930
# Confusion Matrix:
# [[564   8]
#  [  0 560]]

# %%
plt.figure(figsize=(12, 6))
plt.plot(history_ann_nopca.history['loss'], label='Training Loss')
plt.plot(history_ann_nopca.history['val_loss'], label='Validation Loss')
plt.title('Loss Function')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()
